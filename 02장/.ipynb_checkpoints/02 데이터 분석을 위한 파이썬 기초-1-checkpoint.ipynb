# %% [markdown]
# ### **1. 변수**

# %%
#코드 2-1
#변수에 '철수'를 담기
name = '철수'
print(name)

#변수에 '영희'를 담기
name = '영희'
print(name)

# %%
#코드 2-2
score

# %%
#코드 2-3
2_name = '철수, 영희'

# %% [markdown]
# ### **2. 파이썬의 상수**

# %%
#코드 2-4
PI = 3.1415
GRAVITY = 9.8
